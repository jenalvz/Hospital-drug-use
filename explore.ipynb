# %%
#pip install pandas
# %matplotlib inline

# %%
#import dependencies
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
from pathlib import Path



#import kaggle dataset
drug_data_to_load = Path("Resources/Drug_Use_Data_from_Selected_Hospitals.csv")
#drug_data_to_load

#read in the data
drug_dataset = pd.read_csv(drug_data_to_load)

#displao the data for preview
drug_dataset.head()


#ran using new_pd environment
# Out:
#    FIGURE SETTING INDICATOR GROUP SUBGROUP  TIME  START_TIME    END_TIME  \
# 0       0      IP       NaN   NaN      NaN     1  01/01/2020  01/31/2020
# 1       0      IP       NaN   NaN      NaN     2  02/01/2020  02/29/2020
# 2       0      IP       NaN   NaN      NaN     3  03/01/2020  03/31/2020
# 3       0      IP       NaN   NaN      NaN     4  04/01/2020  04/30/2020
# 4       0      IP       NaN   NaN      NaN     5  05/01/2020  05/31/2020
#
#      VALUE MEASURE
# 0  38478.0   Count
# 1  35754.0   Count
# 2  32745.0   Count
# 3  26179.0   Count
# 4  29679.0   Count
